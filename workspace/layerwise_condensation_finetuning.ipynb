# %%
import sys
import os
import torch
import torch.nn as nn
from torchvision import transforms, datasets
import numpy as np
import time
import random
import math
import copy
  
import json
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

import struct
# Out:
# /home/lanxiang/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
cola_3_to_8_ep1 = [0.57, 0.61, 0.52, 0.53, 0.49, 0.36, 0.18]
layer_removed = [0, 1, 2, 3, 4, 5, 6]

# %%
cola_4_to_9_ep1 = [0.58, 0.56, 0.56, 0.52, 0.47, 0.33, 0.19]
layer_removed = [0, 1, 2, 3, 4, 5, 6]

# %%
cola_5_to_10_ep1 = [0.53, 0.59, 0.56, 0.53, 0.42, 0.33, 0.21]
layer_removed = [0, 1, 2, 3, 4, 5, 6]

# %%
figure(figsize=(12, 12))

plt.axhline(y=0.47, color='y', linestyle='--', label='DistilBERT')

plt.axhline(y=0.58, color='r', linestyle='--', label='BERT')

plt.plot(layer_removed, cola_3_to_8_ep1, color='b', label='Iterative (Top) Layer Dropping, removed after training 1 epoch')
#plt.plot(layer_removed, cola_4_to_9_ep1, color='g', label='bert removing layer 4 to 9, removed after training 1 epoch')
#plt.plot(layer_removed, cola_5_to_10_ep1, color='y', label='bert removing layer 5 to 10, removed after training 1 epoch')
#plt.title("Layerwise Condensation Finetuning on BERT, test on COLA")
plt.xlabel("Number of Layers Removed")
plt.ylabel("Performance")
plt.legend()

plt.show()
